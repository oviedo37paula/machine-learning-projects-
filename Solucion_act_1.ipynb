# %%
import pandas as pd
import numpy as np

# %%
activity_01 = pd.read_csv('/activity_1_ml.csv')

# %%
activity_01
# Out:
#       WAGE  EDUC  EXPER  GENDER FAM_STATUS  TENURE
# 0    10.00     0      3    male    MARRIED       2
# 1     3.50     0      2  female      alone       0
# 2     3.30     0      5  female     single       0
# 3     5.00     0     15    male    married       5
# 4    11.25     0     28    male    married      25
# ..     ...   ...    ...     ...        ...     ...
# 547   3.00     0      9    male        NaN       0
# 548   7.63     0      8  female     single       4
# 549   4.50     0     36  female    married       6
# 550    NaN     0     28    male    married       3
# 551   6.36     0      8    male    married       1
#
# [552 rows x 6 columns]

# %%
#Errores implicitos
activity_01.duplicated().sum()
# Out:
# 17

# %%
#Se eliminaran los errores encontrados
activity_01.drop_duplicates(inplace=True)
activity_01.reset_index(drop=True, inplace=True)

# %%
activity_01
# Out:
#       WAGE  EDUC  EXPER  GENDER FAM_STATUS  TENURE
# 0    10.00     0      3    male    MARRIED       2
# 1     3.50     0      2  female      alone       0
# 2     3.30     0      5  female     single       0
# 3     5.00     0     15    male    married       5
# 4    11.25     0     28    male    married      25
# ..     ...   ...    ...     ...        ...     ...
# 530   2.90     0      1    male     single       2
# 531   3.25     0     14  female    married       2
# 532   7.63     0      8  female     single       4
# 533    NaN     0     28    male    married       3
# 534   6.36     0      8    male    married       1
#
# [535 rows x 6 columns]

# %%
# verificar variables #Fam status
activity_01['FAM_STATUS'].unique()

# %%
dictio_correct_1 ={'MARRIED':'married',
                'SINGLE':'single',
                'alone':'single',
                'married' : 'married',
                'single' : 'single'}

# %%
activity_01['FAM_STATUS']=activity_01['FAM_STATUS'].map(dictio_correct_1)

# %%
activity_01['FAM_STATUS'].unique()
# Out:
# array(['married', 'single', nan], dtype=object)

# %%
#gender
activity_01['GENDER'].unique()
# Out:
# array(['male', 'female', 'MALE', 'FEMALE', 'man', 'woman', nan],
#       dtype=object)

# %%
dictio_correct_2 ={'male':'male',
                'female':'female',
                'MALE':'male',
                'FEMALE' : 'female',
                   'man' : 'male',
                   'woman' : 'female'}

# %%
activity_01['GENDER']=activity_01['GENDER'].map(dictio_correct_2)

# %%
activity_01['GENDER'].unique()
# Out:
# array(['male', 'female', nan], dtype=object)

# %%
#Valores nulos
activity_01.isna().sum()
# Out:
# WAGE          61
# EDUC           0
# EXPER          0
# GENDER         3
# FAM_STATUS    81
# TENURE         0
# dtype: int64

# %%
activity_01.dropna()
# Out:
#       WAGE  EDUC  EXPER  GENDER FAM_STATUS  TENURE
# 0    10.00     0      3    male    married       2
# 1     3.50     0      2  female     single       0
# 2     3.30     0      5  female     single       0
# 3     5.00     0     15    male    married       5
# 4    11.25     0     28    male    married      25
# ..     ...   ...    ...     ...        ...     ...
# 529   6.46     0     27    male    married       0
# 530   2.90     0      1    male     single       2
# 531   3.25     0     14  female    married       2
# 532   7.63     0      8  female     single       4
# 534   6.36     0      8    male    married       1
#
# [403 rows x 6 columns]

# %%
#visualizacion de la data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# %%
#Primera grafica : Tabla de frecuencias
fem = activity_01['GENDER'].value_counts()
fem.index = ['m', 'f']

# %%
fem
# Out:
# m    280
# f    252
# Name: GENDER, dtype: int64

# %%
plt.bar(fem.index, fem.values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Población esta conformada por 532 hombres 280
# y mujeres son 252

# %%
sns.boxplot(data=activity_01, x='FAM_STATUS', y='WAGE', hue='GENDER') #segunda grafica bloxplot
# Out:
# <Axes: xlabel='FAM_STATUS', ylabel='WAGE'>

# %% [markdown]
# En el boxplot Esta los estatus,sexo, etc
# Nos da a entender que un hombre casado gana mucho mas mientras que la mujer casada gana menos.
#
# por otro lado la mujer soltera tiende a ganar mas que la casada por ende dice que los hombres buscarian casarse mas para ganar ,mas y las mujeres quedarse solas para ganar mas.
