# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# %%
activity_02 = pd.read_csv("/content/activity_2_ml.csv")

# %%
activity_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 353 non-null    int64
#  1   AGE                  353 non-null    int64
#  2   DISTANCE_BUS         353 non-null    float64
#  3   DISTANCE_INTERSTATE  353 non-null    float64
#  4   PRICE                283 non-null    float64
#  5   ROOMS                353 non-null    int64
#  6   AREA                 353 non-null    int64
#  7   LAND                 353 non-null    float64
#  8   BATHS                353 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 24.9 KB

# %%
activity_02
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 348  1981   51        2000.0               5000.0   50000.0      5  1140
# 349    81    1       22000.0              24000.0  162000.0      7  2656
# 350    78    3       12000.0              12000.0   64900.0      7  2856
# 351  1978   26       20000.0              22000.0   58000.0      6  1356
# 352  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
#Errores implicitos
activity_02.duplicated().sum()
# Out:
# 12

# %%
activity_02
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 336  1981   51        2000.0               5000.0   50000.0      5  1140
# 337    81    1       22000.0              24000.0  162000.0      7  2656
# 338    78    3       12000.0              12000.0   64900.0      7  2856
# 339  1978   26       20000.0              22000.0   58000.0      6  1356
# 340  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
dictio_correct_2={1978:1978,
                  1981:1981,
                  78:1978,
                  81:1981}

# %%
activity_02['YEAR']=activity_02['YEAR'].map(dictio_correct_2)
activity_02['YEAR'].unique()
# Out:
# array([1978, 1981])

# %%
#Se eliminaran los errores encontrados
activity_02.drop_duplicates(inplace=True)
activity_02.reset_index(drop=True, inplace=True)

# %%
#Errores implicitos
activity_02.duplicated().sum()
# Out:
# 0

# %%
activity_02
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3    1981    0       10000.0              13000.0  216000.0      7  2548
# 4    1981    0       25000.0              25000.0  125000.0      7  2208
# ..    ...  ...           ...                  ...       ...    ...   ...
# 257  1981    2       20000.0              20000.0  158000.0      7  2627
# 258  1981   51        2000.0               5000.0   50000.0      5  1140
# 259  1981    1       22000.0              24000.0  162000.0      7  2656
# 260  1978    3       12000.0              12000.0   64900.0      7  2856
# 261  1978   26       20000.0              22000.0   58000.0      6  1356
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
#Valores nulos
activity_02.isna().sum()
# Out:
# YEAR                   0
# AGE                    0
# DISTANCE_BUS           0
# DISTANCE_INTERSTATE    0
# PRICE                  0
# ROOMS                  0
# AREA                   0
# LAND                   0
# BATHS                  0
# dtype: int64

# %%
 activity_02.dropna()
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3    1981    0       10000.0              13000.0  216000.0      7  2548
# 4    1981    0       25000.0              25000.0  125000.0      7  2208
# ..    ...  ...           ...                  ...       ...    ...   ...
# 257  1981    2       20000.0              20000.0  158000.0      7  2627
# 258  1981   51        2000.0               5000.0   50000.0      5  1140
# 259  1981    1       22000.0              24000.0  162000.0      7  2656
# 260  1978    3       12000.0              12000.0   64900.0      7  2856
# 261  1978   26       20000.0              22000.0   58000.0      6  1356
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
activity_02  = activity_02.dropna()

# %%
año = activity_02['YEAR'].value_counts()
año.index = [1981, 1978]

# %%
año
# Out:
# 1981    144
# 1978    118
# Name: YEAR, dtype: int64

# %%
plt.bar(año.index, año.values)

# %%
rooms = activity_02['ROOMS'].value_counts()
rooms.index = [1, 2, 3, 4, 5, 6, 7]

# %%
rooms
# Out:
# 1    133
# 2     82
# 3     26
# 4     11
# 5      7
# 6      2
# 7      1
# Name: ROOMS, dtype: int64

# %%
plt.bar(rooms.index, rooms.values)

# %%
baths = activity_02['BATHS'].value_counts()
baths.index = [1, 2, 3, 4]

# %%
baths
# Out:
# 1    121
# 2     95
# 3     42
# 4      4
# Name: BATHS, dtype: int64

# %%
plt.bar(baths.index, baths.values)
# Out:
# <BarContainer object of 4 artists>

# %%
activity_02['AGE'].plot(kind='hist', bins=20, title='AGE')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
activity_02['DISTANCE_BUS'].plot(kind='hist', bins=20, title='DISTANCE_BUS')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
activity_02['DISTANCE_INTERSTATE'].plot(kind='hist', bins=20, title='DISTANCE_INTERSTATE')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
activity_02['PRICE'].plot(kind='hist', bins=20, title='PRICE')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
activity_02['AREA'].plot(kind='hist', bins=20, title='AREA')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
activity_02['LAND'].plot(kind='hist', bins=20, title='LAND')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS YEAR
activity_02.plot(kind='scatter', x='YEAR', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS HABITACIONES
activity_02.plot(kind='scatter', x='ROOMS', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS BAÑOS
activity_02.plot(kind='scatter', x='BATHS', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS DISTANCE_BUS
activity_02.plot(kind='scatter', x='DISTANCE_BUS', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS DISTANCE_INTERESTATAL
activity_02.plot(kind='scatter', x='DISTANCE_INTERSTATE', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS AREA
activity_02.plot(kind='scatter', x='AREA', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#PRECIO VS LAND
activity_02.plot(kind='scatter', x='LAND', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
