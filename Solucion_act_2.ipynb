# %%
import pandas as pd
import numpy as np

# %%
activity_02 = pd.read_csv('/content/activity_2_ml (1).csv')

# %%
activity_02
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 348  1981   51        2000.0               5000.0   50000.0      5  1140
# 349    81    1       22000.0              24000.0  162000.0      7  2656
# 350    78    3       12000.0              12000.0   64900.0      7  2856
# 351  1978   26       20000.0              22000.0   58000.0      6  1356
# 352  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
#Errores implicitos
activity_02.duplicated().sum()
# Out:
# 12

# %%
#Se eliminaran los errores encontrados
activity_02.drop_duplicates(inplace=True)
activity_02.reset_index(drop=True, inplace=True)

# %%
activity_02
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 336  1981   51        2000.0               5000.0   50000.0      5  1140
# 337    81    1       22000.0              24000.0  162000.0      7  2656
# 338    78    3       12000.0              12000.0   64900.0      7  2856
# 339  1978   26       20000.0              22000.0   58000.0      6  1356
# 340  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
#Errores implicitos
activity_02.duplicated().sum()
# Out:
# 0

# %%
#YEAR

from matplotlib import pyplot as plt
activity_02['YEAR'].plot(kind='hist', bins=20, title='YEAR')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#Valores nulos
activity_02.isna().sum()
# Out:
# YEAR                    0
# AGE                     0
# DISTANCE_BUS            0
# DISTANCE_INTERSTATE     0
# PRICE                  70
# ROOMS                   0
# AREA                    0
# LAND                    0
# BATHS                   0
# dtype: int64

# %%
activity_02.dropna()
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# 5      81    0       25000.0              25000.0  125000.0      7  2208
# ..    ...  ...           ...                  ...       ...    ...   ...
# 335  1981    2       20000.0              20000.0  158000.0      7  2627
# 336  1981   51        2000.0               5000.0   50000.0      5  1140
# 337    81    1       22000.0              24000.0  162000.0      7  2656
# 338    78    3       12000.0              12000.0   64900.0      7  2856
# 339  1978   26       20000.0              22000.0   58000.0      6  1356
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
#DISTANCE_INTERSTATE vs PRICE

from matplotlib import pyplot as plt
activity_02.plot(kind='scatter', x='DISTANCE_INTERSTATE', y='PRICE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Esta gráfica nos indica como la mayoria de la población que nos da el modelo de la actividad 2 va a una distancia aproximada de 12.500 entre estados, a su vez al rener el mayor flujo es el recorrido que mas elevado tiene el precio.
# A su vez nos muestra como el resto de distancias presenta un flujo de movimientos similar en cuanto a volumen y precios llegando a tener precios aproximados similares en una distancia de 5000 a una distancia de 30000
